# %%
# requirements
# !tar xvf ./update_smart_ai.tar
# Out:
# ./update_smart_ai/
# ./update_smart_ai/update.py
# ./update_smart_ai/updater.sh
# ./update_smart_ai/.git/
# ./update_smart_ai/.git/HEAD
# ./update_smart_ai/.git/index
# ./update_smart_ai/.git/objects/
# ./update_smart_ai/.git/objects/pack/
# ./update_smart_ai/.git/objects/pack/pack-2f838cb68d65f14a6f80fe415be0027b6518f3c3.pack
# ./update_smart_ai/.git/objects/pack/pack-2f838cb68d65f14a6f80fe415be0027b6518f3c3.idx
# ./update_smart_ai/.git/objects/info/
# ./update_smart_ai/.git/branches/
# ./update_smart_ai/.git/refs/
# ./update_smart_ai/.git/refs/tags/
# ./update_smart_ai/.git/refs/heads/
# ./update_smart_ai/.git/refs/heads/main
# ./update_smart_ai/.git/refs/remotes/
# ./update_smart_ai/.git/refs/remotes/origin/
# ./update_smart_ai/.git/refs/remotes/origin/HEAD
# ./update_smart_ai/.git/config
# ./update_smart_ai/.git/info/
# ./update_smart_ai/.git/info/exclude
# ./update_smart_ai/.git/hooks/
# ./update_smart_ai/.git/hooks/pre-commit.sample
# ...

# %%
# %cd ./update_smart_ai/pexpect-master
# !python3 setup.py install --user
# Out:
# [Errno 2] No such file or directory: './update_smart_ai/pexpect-master'
# /home/pi/workspace/update_smart_ai/pexpect
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'project_urls'
#   warnings.warn(msg)
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'install_requires'
#   warnings.warn(msg)
# running install
# running build
# running build_py
# running install_lib
# running install_egg_info
# Removing /home/pi/.local/lib/python3.7/site-packages/pexpect-4.8.0.egg-info
# Writing /home/pi/.local/lib/python3.7/site-packages/pexpect-4.8.0.egg-info
